# %%
# Read the data from the csv file and plot the bar graph
import pandas as pd

# Read the data from the csv file
data = pd.read_csv("../data/result.csv")
print(data)

# plot the bar graph
data.plot.bar(x="Approach", y="Result", rot=70, title="Fractional Knapsack")
# Out:
#                                          Approach       Result
# 0  Fractional knapsack for profit by weight ratio  7566.857143
# 1          Fractional Knapsack for minimum weight  6265.745763
# 2          Fractional Knapsack for maximum profit  7076.083333
# <Axes: title={'center': 'Fractional Knapsack'}, xlabel='Approach'>
